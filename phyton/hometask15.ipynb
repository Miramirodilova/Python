# %%
import requests
import time
from datetime import datetime

api_key = 'b1f4ec0a86974bafb71124001240312'  
cityes = ['Moscow', 'New York'] 

while True:
    print(f"Updated at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')} (System Time)\n")
    
    for city in cityes:
        url = f'https://api.weatherapi.com/v1/current.json?key={api_key}&q={city}'

        try:
            response = requests.get(url)
            data = response.json()

            location = data['location']['region']
            country = data['location']['country']
            temperature = data['current']['temp_c']
            condition = data['current']['condition']['text']
            local_time = data['location']['localtime'] 
            print(f'Weather in {location}, {country} ({local_time}): {condition}')
            print(f'Temperature: {temperature}⁰C\n')

        except Exception as e:
            print(f"Error fetching data for {city}: {e}")

    print("-" * 40)
    time.sleep(1)
# Out:
# Updated at: 2025-02-10 14:21:18 (System Time)
#
# Weather in Moscow City, Russia (2025-02-10 12:21): Mist
# Temperature: -3.7⁰C
#
# Weather in New York, United States of America (2025-02-10 04:31): Partly cloudy
# Temperature: 0.6⁰C
#
# ----------------------------------------
# Updated at: 2025-02-10 14:21:20 (System Time)
#
# Weather in Moscow City, Russia (2025-02-10 12:21): Mist
# Temperature: -3.7⁰C
#
# Weather in New York, United States of America (2025-02-10 04:31): Partly cloudy
# Temperature: 0.6⁰C
#
# ----------------------------------------
# Updated at: 2025-02-10 14:21:22 (System Time)
#
# Weather in Moscow City, Russia (2025-02-10 12:21): Mist
# Temperature: -3.7⁰C
#
# Weather in New York, United States of America (2025-02-10 04:31): Partly cloudy
# Temperature: 0.6⁰C
#
# ----------------------------------------
# Updated at: 2025-02-10 14:21:23 (System Time)
#
# Weather in Moscow City, Russia (2025-02-10 12:21): Mist
# Temperature: -3.7⁰C
#
# Weather in New York, United States of America (2025-02-10 04:31): Partly cloudy
# Temperature: 0.6⁰C
#
# ----------------------------------------
# Updated at: 2025-02-10 14:21:25 (System Time)
#
# Weather in Moscow City, Russia (2025-02-10 12:21): Mist
# Temperature: -3.7⁰C
#
# Weather in New York, United States of America (2025-02-10 04:31): Partly cloudy
# Temperature: 0.6⁰C
#
# ----------------------------------------
# Updated at: 2025-02-10 14:21:27 (System Time)
#
# Weather in Moscow City, Russia (2025-02-10 12:21): Mist
# Temperature: -3.7⁰C
#
# Weather in New York, United States of America (2025-02-10 04:31): Partly cloudy
# Temperature: 0.6⁰C
#
# ----------------------------------------
# Updated at: 2025-02-10 14:21:28 (System Time)
#
# Weather in Moscow City, Russia (2025-02-10 12:21): Mist
# Temperature: -3.7⁰C
#
# Weather in New York, United States of America (2025-02-10 04:31): Partly cloudy
# Temperature: 0.6⁰C
#
# ----------------------------------------
# Updated at: 2025-02-10 14:21:30 (System Time)
#
# Weather in Moscow City, Russia (2025-02-10 12:21): Mist
# Temperature: -3.7⁰C
#
# Weather in New York, United States of America (2025-02-10 04:31): Partly cloudy
# Temperature: 0.6⁰C
#
# ----------------------------------------
# Updated at: 2025-02-10 14:21:32 (System Time)
#
# Weather in Moscow City, Russia (2025-02-10 12:21): Mist
# Temperature: -3.7⁰C
#
# Weather in New York, United States of America (2025-02-10 04:31): Partly cloudy
# Temperature: 0.6⁰C
#
# ----------------------------------------
# Updated at: 2025-02-10 14:21:33 (System Time)
#
# Weather in Moscow City, Russia (2025-02-10 12:21): Mist
# Temperature: -3.7⁰C
#
# Weather in New York, United States of America (2025-02-10 04:31): Partly cloudy
# Temperature: 0.6⁰C
#
# ----------------------------------------
# Updated at: 2025-02-10 14:21:35 (System Time)
#
# Weather in Moscow City, Russia (2025-02-10 12:21): Mist
# Temperature: -3.7⁰C
#
# Weather in New York, United States of America (2025-02-10 04:31): Partly cloudy
# Temperature: 0.6⁰C
#
# ----------------------------------------
# Updated at: 2025-02-10 14:21:37 (System Time)
#
# Weather in Moscow City, Russia (2025-02-10 12:21): Mist
# Temperature: -3.7⁰C
#
# Weather in New York, United States of America (2025-02-10 04:31): Partly cloudy
# Temperature: 0.6⁰C
#
# ----------------------------------------
# Updated at: 2025-02-10 14:21:38 (System Time)
#
# Weather in Moscow City, Russia (2025-02-10 12:21): Mist
# Temperature: -3.7⁰C
#
# Weather in New York, United States of America (2025-02-10 04:31): Partly cloudy
# Temperature: 0.6⁰C
#
# ----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 30
#      27         print(f"Error fetching data for {city}: {e}")
#      29 print("-" * 40)
# ---> 30 time.sleep(1)
#
# KeyboardInterrupt:
